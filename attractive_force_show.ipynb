# %%
import ex_render
ex_render.display_movie(ex_render.render_disk_frame, 'init_setting.gsd')

# %%
ex_render.display_movie(ex_render.render_disk_frame, 'trajectory_all.gsd')

# %%
import ex_render
ex_render.display_movie(ex_render.render_disk_frame, 'trajectory_levy.gsd')
