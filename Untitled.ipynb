# %%
import ex_render
ex_render.display_movie(ex_render.render_sphere_frame, 'trajectory.gsd')

# %%
# import poisson_disc
# import hoomd
# import hoomd.md
# import fresnel
# import numpy as np

# hoomd.context.initialize("")
# base_params = dict()
# np.random.seed(1) # fixed num

# L = 50
# r = 0.5
# base_params['rd'] = 0.5
#     #N_base = m

#     #
#     #x = np.linspace(-L / 2, L / 2, m, endpoint=False)
#     #position = list(itertools.product(x, repeat=3))
#     # the position of base
#     #pos = L*np.random.rand(base_params['N'],10)

# pos = L * poisson_disc.Bridson_sampling(dims=np.array([1.0,1.0]),
#                                             radius=1.5*2*base_params['rd']/L) - np.array([L/2,L/2])
#     #plt.scatter(pos[:,0],pos[:,1])
#     #plt.show()
# base_params['N'] = len(pos)
# pos_z = np.zeros([base_params['N'],1])
# base_params['pos'] = tuple(map(tuple, np.hstack([pos,pos_z])))


# snapshot = hoomd.data.make_snapshot(N = base_params['N'],
#                                         box=hoomd.data.boxdim(Lx=L,Ly=L,Lz=0.1*L),
#                                         particle_types=['A','B'],
#                                         )

# idx = np.random.choice(base_params['N'], int(base_params['N']/4), replace=False)

# snapshot.particles.typeid[:] = 1
# snapshot.particles.typeid[idx] = 0

# snapshot.particles.diameter[:] = base_params['rd'] * snapshot.particles.diameter
    
    
# system = hoomd.init.read_snapshot(snapshot)
    
# import ex_render
# ex_render.render_sphere_frame(system.take_snapshot())
